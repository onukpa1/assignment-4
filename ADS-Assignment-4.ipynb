# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv ('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.set_index('customerID', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.head(10)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 1452-KIOVK    Male              0      No        Yes      22          Yes
# 6713-OKOMC  Female              0      No         No      10           No
# 7892-POOKP  Female              0     Yes         No      28          Yes
# 6388-TABGU    Male              0      No        Yes      62          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# ...

# %%
df['Churn'].value_counts().head()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.loc[df['MonthlyCharges'] > 60]
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 1452-KIOVK    Male              0      No        Yes      22          Yes
# 7892-POOKP  Female              0     Yes         No      28          Yes
# 8091-TTVAX    Male              0     Yes         No      58          Yes
# ...            ...            ...     ...        ...     ...          ...
# 7750-EYXWZ  Female              0      No         No      12           No
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ##### 1 (demographics) the most demographics popular with the telco brand?
#          a) Male and Non-senior citizens
#         b) Non-senior citizens (Adults/Middle Age)

# %%
df['gender'].value_counts().head()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['SeniorCitizen'].value_counts().head()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
sns.countplot(x="StreamingTV",hue = 'Churn', data=df)
plt.show()

# %% [markdown]
# #### (Services) services contributing to higher monthly charges and churning
#
#          Phone service,
#          Multiple Lines
#          Movies streaming

# %%
#phone service 6361

df['PhoneService'].value_counts().head()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
df['MultipleLines'].value_counts().head()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
# internet service    5517

df['InternetService'].value_counts().head()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['OnlineSecurity'].value_counts().head()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
df['OnlineBackup'].value_counts().head()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
df['DeviceProtection'].value_counts().head()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
df['TechSupport'].value_counts().head()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
df['StreamingTV'].value_counts().head()
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %%
# Movies streaming 2785

df['StreamingMovies'].value_counts().head()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %% [markdown]
# ### Multiple Lines

# %%
sns.barplot(data=df,
            x="MultipleLines",
            y="MonthlyCharges", hue = "Churn" 
            )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Phone service

# %%
sns.barplot(data=df,
            x="PhoneService",
            y="MonthlyCharges", hue = "Churn" 
            )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Movies streaming

# %%
sns.barplot(data=df,
            x="StreamingMovies",
            y="MonthlyCharges", hue = "Churn"
            )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### type of contract which would encourage customer retention is contract with higher counts "month-to-month"

# %%
df['Contract'].value_counts().head()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %% [markdown]
# ## Payment

# %%
df['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ### Should the company strictly go paperless for their monthly billings as a technique of keeping their customers and why
#     Yes, because from the dataset majority of the customers 4171 out of 7043 went for a paperless billing

# %%
pp_less = df['PaperlessBilling'].value_counts()
pp_less
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %% [markdown]
# # checking for duplicates

# %%
duplicate = df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 22
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 9117-SHLZX    Male              0      No         No       1          Yes
# 1934-SJVJK    Male              0      No         No       1          Yes
# 8605-ITULD  Female              0      No         No       1          Yes
# 9804-ICWBG    Male              0      No         No       1          Yes
# 3247-MHJKM    Male              0      No         No       1          Yes
# 5996-DAOQL    Male              0      No         No       1          Yes
# 2668-TZSPS    Male              0      No         No       1          Yes
# 2636-ALXXZ  Female              1      No         No       1          Yes
# 7096-UCLNH    Male              0      No         No       1          Yes
# 5356-RHIPP    Male              0      No         No       1          Yes
# 7434-SHXLS  Female              0      No         No       1          Yes
# ...

# %%
pp = df['PaperlessBilling'].value_counts()
pp
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
df.drop_duplicates(inplace = True)
dpl = df.duplicated()
dpl.sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...
